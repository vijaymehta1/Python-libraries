# %%
import numpy as np
import pandas as pd

# %%
country = ["india ", "uk" ,"us" ,"china" , "japan" , "france" ]
pd.Series(country)
# Out:
# 0    india
# 1        uk
# 2        us
# 3     china
# 4     japan
# 5    france
# dtype: object

# %%
subject = ["english","hindi","maths", "cse"]
marks = [90,91,92,93]
marks_series =pd.Series(marks,index=subject,name="vijay'smarks")
print(marks_series)
# Out:
# english    90
# hindi      91
# maths      92
# cse        93
# Name: vijay'smarks, dtype: int64

# %%
vk = pd.read_csv("kohli_ipl.csv",index_col='match_no')
print(vk)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
vk.head(3)
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
vk.tail(4)
# Out:
#           runs
# match_no
# 212         20
# 213         73
# 214         25
# 215          7

# %%
vk.sample(4)
# Out:
#           runs
# match_no
# 78          32
# 23          19
# 89          21
# 8            0
