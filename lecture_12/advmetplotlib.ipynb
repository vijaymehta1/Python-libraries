# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# Colored Scatterplots

# %%
iris = pd.read_csv('iris.csv',encoding_errors='ignore')
plt.scatter(iris['SepalWidthCm'],iris['PetalWidthCm'])
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_25380\202875705.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
# cmap and alpha 
plt.scatter(iris['SepalWidthCm'],iris['PetalWidthCm'],c=iris['Species'],cmap="jet", alpha=0.8)
plt.xlabel('SepalWidthCm')
plt.ylabel('PetalWidthCm')
plt.colorbar()
plt.show()

# %% [markdown]
# Plot size

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalWidthCm'],iris['PetalWidthCm'],c=iris['Species'],cmap="jet", alpha=0.8)
plt.xlabel('SepalWidthCm')
plt.ylabel('PetalWidthCm')
plt.colorbar()
plt.show()

# %% [markdown]
# Annotations

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2')
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4',fontdict={'size':12,'color':'brown'})
# Out:
# Text(4, 8, 'Point 4')

# %%
batter = pd.read_csv('batter.csv')
batter.head(1)
# Out:
#     batter  runs        avg  strike_rate
# 0  V Kohli  6634  36.251366   125.977972

# %%
batter.shape
# Out:
# (605, 4)

# %%
sample_df = batter.head(100).sample(20,random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.figure(figsize=(15,7))
plt.scatter(sample_df['strike_rate'],sample_df['avg'],s = sample_df['runs']/10)
for i in range(sample_df.shape[0]):
    plt.text(sample_df['strike_rate'].values[i],sample_df['avg'].values[i],sample_df['batter'].values[i])

# %% [markdown]
# Horizontal and Vertical lines

# %%
plt.figure(figsize=(15,7))
plt.scatter(sample_df['strike_rate'],sample_df['avg'],s = sample_df['runs']/10)
plt.axhline(35,color = 'red')
plt.axvline(140,color = 'green')
for i in range(sample_df.shape[0]):
    plt.text(sample_df['strike_rate'].values[i],sample_df['avg'].values[i],sample_df['batter'].values[i])

# %% [markdown]
# subplots

# %%
batter
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig ,ax = plt.subplots(figsize = (15,6))
ax.scatter(batter['avg'],batter['strike_rate'])
ax.set_xlabel('runs')
ax.set_ylabel('strike rate ')
ax.set_title('avg vs strike rate ')
fig.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_25380\3913973531.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# batter dataset
fig,ax = plt.subplots(nrows=2,ncols=1,sharey=True,figsize =(20,12))
ax[0].scatter(batter['runs'],batter['strike_rate'],color='red')
ax[1].scatter(batter['avg'],batter['strike_rate'],color = 'green')
ax[0].set_title('runs Vs Strike Rate')
ax[0].set_ylabel('Strike Rate')


ax[1].set_title('Avg Vs strike rate ')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax[0,0].scatter(batter['runs'],batter['strike_rate'],color='red')
ax[0,1].scatter(batter['avg'],batter['runs'])
ax[1,0].hist(batter['avg'])
ax[1,1].hist(batter['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(batter['avg'],batter['strike_rate'],color='red')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(batter['runs'])

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batter['avg'])
# Out:
# (array([102., 125., 103.,  82.,  78.,  43.,  22.,  14.,   2.,   1.]),
#  array([ 0.        ,  5.56666667, 11.13333333, 16.7       , 22.26666667,
#         27.83333333, 33.4       , 38.96666667, 44.53333333, 50.1       ,
#         55.66666667]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3D Scatter Plots

# %%
fig = plt.figure(figsize=(15,6))
ax = plt.subplot(projection ='3d')
ax.scatter3D(batter['runs'],batter['avg'],batter['strike_rate'],marker='+')
ax.set_title('runs vs avg vs strike rate')
ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('SR')
# Out:
# Text(0.5, 0, 'SR')

# %% [markdown]
# 3D Line Plot

# %%
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]
fig = plt.figure()
ax = plt.subplot(projection = '3d')
ax.scatter3D(x,y,z)
ax.plot3D(x,y,z,color ='red')

# %% [markdown]
# 3D Surface Plots

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx, yy = np.meshgrid(x,y)
z = xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.log(xx)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_25380\684431574.py:1: RuntimeWarning: invalid value encountered in log
#   z = np.sin(xx) + np.log(xx)

# %% [markdown]
# Contour Plots

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
xx, yy = np.meshgrid(x,y)
z = xx**2 + yy**2
z.shape
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)
