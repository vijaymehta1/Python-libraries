# %%
import numpy as np
import pandas as pd

# %%
matches= pd.read_csv('batsman_runs_ipl (1).csv')
matches
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# 1 . value_count()

# %%
s = pd.Series([1,2,3,1,2,3,4])
s.value_counts()
# Out:
# 1    2
# 2    2
# 3    2
# 4    1
# Name: count, dtype: int64

# %%
ipl[ipl['MatchNumber']=='Final']['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# HH Pandya       1
# F du Plessis    1
# TA Boult        1
# JJ Bumrah       1
# SR Watson       1
# KH Pandya       1
# BCJ Cutting     1
# RG Sharma       1
# MK Pandey       1
# KA Pollard      1
# MS Bisla        1
# M Vijay         1
# SK Raina        1
# A Kumble        1
# YK Pathan       1
# Name: count, dtype: int64

# %%
mask = ~ipl['MatchNumber'].str.isdigit()
special_matches = ipl[mask]

# %%
result = special_matches['Player_of_Match'].value_counts()
print(result)
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # how many matches each team has played

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
#  sort_values(series and dataframe) -> ascending -> na_position -> inplace -> multiple cols

# %%
x = pd.Series([1,2,3,8,5,6,7])
x.sort_values(ascending=False)
# Out:
# 3    8
# 6    7
# 5    6
# 4    5
# 2    3
# 1    2
# 0    1
# dtype: int64

# %%
movies = pd.read_csv("movies (1).csv")
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.sort_values(['year_of_release','title_x']).head(1)
# Out:
#           title_x    imdb_id  \
# 1575  Aalavandhan  tt0294264
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       wiki_link      title_y original_title  \
# 1575  https://en.wikipedia.org/wiki/Aalavandhan  Aalavandhan    Aalavandhan
#
#       is_adult  year_of_release runtime           genres  imdb_rating  \
# 1575         0             2001     177  Action|Thriller          7.1
#
#       imdb_votes                                              story  \
# 1575        1746  The story follows Abhay (Haasan) who has a dis...
#
#                                                 summary       tagline  \
# 1575  A psychopath tries to protect his twin brother...  The Fearless
#
#                                                  actors      wins_nominations  \
# 1575  Kamal Haasan|Raveena Tandon|Manisha Koirala|Ki...  1 win & 1 nomination
#
#                   release_date
# ...

# %% [markdown]
# # rank(series)

# %%
runs = pd.read_csv("batsman_runs_ipl (1).csv")
runs
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
runs["batsman_rank"] = runs['batsman_run'].rank(ascending=False)
runs.sort_values('batsman_run')
# Out:
#              batter  batsman_run  batsman_rank
# 570  V Pratap Singh            0         594.0
# 593   Y Prithvi Raj            0         594.0
# 269          KR Sen            0         594.0
# 595      YA Abdulla            0         594.0
# 249         K Yadav            0         594.0
# ..              ...          ...           ...
# 493        SK Raina         5536           5.0
# 430       RG Sharma         5881           4.0
# 130       DA Warner         5883           3.0
# 462        S Dhawan         6244           2.0
# 569         V Kohli         6634           1.0
#
# [605 rows x 3 columns]

# %% [markdown]
# # sort_index(series and dataframe)

# %% [markdown]
# # set_index(dataframe) -> inplace

# %%
runs.set_index('batter',inplace=True)

# %%
runs
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %% [markdown]
# # reset_index(series + dataframe) -> drop parameter

# %%
runs.reset_index()
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]
